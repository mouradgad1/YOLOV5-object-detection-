# %% [markdown]
# <a href="https://colab.research.google.com/github/mouradgad1/YOLOV5-object-detection-/blob/main/Yolov5-Face-Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # Clone YOLOv5 repository
# %cd yolov5
# !pip install -r requirements.txt  # Install dependencies
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17752, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 17752 (delta 66), reused 36 (delta 36), pack-reused 17643 (from 4)
# Receiving objects: 100% (17752/17752), 17.16 MiB | 20.85 MiB/s, done.
# Resolving deltas: 100% (12051/12051), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.7 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="TMbHRSx8aNqr9ZQXQg9A")
project = rf.workspace("cat-area").project("face-detection-mik1i-pkzps")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Face-Detection-1 in yolov5pytorch:: 100%|██████████| 2747/2747 [00:00<00:00, 4281.46it/s]

# %%
import yaml

yaml_path = "/content/yolov5/Face-Detection-1/data.yaml"

with open(yaml_path, 'r') as file:
    data_yaml = yaml.safe_load(file)

data_yaml['train'] = "/content/yolov5/Face-Detection-1/train"
data_yaml['val'] = "/content/yolov5/Face-Detection-1/train"
with open(yaml_path, 'w') as file:
    yaml.dump(data_yaml, file)

print("Updated data.yaml:", data_yaml)
# Out:
# Updated data.yaml: {'names': ['face'], 'nc': 1, 'roboflow': {'license': 'CC BY 4.0', 'project': 'face-detection-mik1i-pkzps', 'url': 'https://universe.roboflow.com/cat-area/face-detection-mik1i-pkzps/dataset/1', 'version': 1, 'workspace': 'cat-area'}, 'test': '../test/images', 'train': '/content/yolov5/Face-Detection-1/train', 'val': '/content/yolov5/Face-Detection-1/train'}

# %%
# !python train.py --img 20 --batch 16 --epochs 50 --data /content/yolov5/Face-Detection-1/data.yaml --weights yolov5s.pt --device 0
# Out:
# python3: can't open file '/content/train.py': [Errno 2] No such file or directory

# %%
# !ls runs/train/exp/weights/
# Out:
# ls: cannot access 'runs/train/exp/weights/': No such file or directory

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --source /content/yolov5/Face-Detection-1/test/images --imgsz 640 --conf-thres 0.4 --iou-thres 0.45 --save-txt --save-conf
# Out:
# python3: can't open file '/content/detect.py': [Errno 2] No such file or directory
